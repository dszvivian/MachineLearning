# %% [markdown]
# # Pandas
#     - Data processing & analysis
#
# ##### Dataframes :
#     2d tabular data structure with labelled axes(rows and columns)

# %%
import pandas as pd

#creating a dataframe

#imprting boston house ds from sklearn
from sklearn.datasets import load_diabetes
ds = load_diabetes()
type(ds)
print(ds)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
#pandas DataFrame
db_df = pd.DataFrame(ds.data,columns = ds.feature_names)
print(db_df)
# Out:
#           age       sex       bmi        bp        s1        s2        s3
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
db_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401  \
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
db_df.shape
# Out:
# (442, 10)

# %% [markdown]
# ### Importing data from .csv files

# %%
addressDf = pd.read_csv('addresses.csv')
type(addressDf)
print(addressDf)
# Out:
#                     John       Doe                 120 jefferson st.
# 0                   Jack  McGinnis                      220 hobo Av.  \
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %% [markdown]
# #### Exporting dataframe to csv file

# %%
db_df.to_csv('diabetics.csv')

# %% [markdown]
# #### create a Df with random values

# %%
import numpy as np

df1 = pd.DataFrame(np.random.rand(20,10))
print(df1.head())
df1.shape
# Out:
#           0         1         2         3         4         5         6
# 0  0.884959  0.945240  0.197542  0.526679  0.817419  0.945441  0.737703  \
# 1  0.840092  0.282967  0.285189  0.644071  0.278538  0.730518  0.304760
# 2  0.025689  0.559997  0.639588  0.965516  0.074129  0.440783  0.402302
# 3  0.600477  0.949692  0.482203  0.175957  0.791529  0.501372  0.411496
# 4  0.606489  0.190882  0.083537  0.517338  0.410359  0.092528  0.770497
#
#           7         8         9
# 0  0.272728  0.338056  0.876268
# 1  0.624198  0.205908  0.947718
# 2  0.761189  0.214488  0.610781
# 3  0.107510  0.602093  0.613272
# 4  0.055930  0.127546  0.814195
# (20, 10)

# %% [markdown]
# #### Getting the info from the dataframe

# %%
df2 = pd.read_csv('diabetics.csv')

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  442 non-null    int64
#  1   age         442 non-null    float64
#  2   sex         442 non-null    float64
#  3   bmi         442 non-null    float64
#  4   bp          442 non-null    float64
#  5   s1          442 non-null    float64
#  6   s2          442 non-null    float64
#  7   s3          442 non-null    float64
#  8   s4          442 non-null    float64
#  9   s5          442 non-null    float64
#  10  s6          442 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 38.1 KB

# %%
#find the Number of missing values
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# age           0
# sex           0
# bmi           0
# bp            0
# s1            0
# s2            0
# s3            0
# s4            0
# s5            0
# s6            0
# dtype: int64

# %%
df2.head()
# Out:
#    Unnamed: 0       age       sex       bmi        bp        s1        s2
# 0           0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821  \
# 1           1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# 2           2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194
# 3           3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# 4           4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
#
#          s3        s4        s5        s6
# 0 -0.043401 -0.002592  0.019907 -0.017646
# 1  0.074412 -0.039493 -0.068332 -0.092204
# 2 -0.032356 -0.002592  0.002861 -0.025930
# 3 -0.036038  0.034309  0.022688 -0.009362
# 4  0.008142 -0.002592 -0.031988 -0.046641

# %%
df2.value_counts('bp')
# Out:
# bp
# -0.005670    21
# -0.040099    21
# -0.026328    20
#  0.021872    15
# -0.033213    14
#              ..
#  0.012680     1
#  0.017293     1
#  0.029894     1
#  0.031065     1
#  0.132044     1
# Name: count, Length: 100, dtype: int64

# %%
#Group the values based on mean
df2.groupby('bp').mean()
# Out:
#            Unnamed: 0       age       sex       bmi        s1        s2
# bp
# -0.112399  224.000000 -0.027310 -0.044642 -0.066563 -0.049727 -0.041397  \
# -0.108956   41.000000 -0.099961 -0.044642 -0.067641 -0.074494 -0.072712
# -0.102070   93.000000 -0.049105 -0.044642 -0.064408 -0.002945 -0.015406
# -0.100934   84.000000  0.001751 -0.044642 -0.039618 -0.029088 -0.030124
# -0.098627  171.000000 -0.020045 -0.044642 -0.046085 -0.075870 -0.059873
# ...               ...       ...       ...       ...       ...       ...
#  0.101058  217.000000  0.074401 -0.044642  0.031517  0.046589  0.036890
#  0.104501  195.500000 -0.007331  0.003019  0.027206  0.016318 -0.015249
#  0.107944  377.666667  0.027178  0.018906  0.002417  0.026409  0.008081
#  0.125158   71.000000 -0.001882 -0.044642  0.033673  0.024574  0.026243
#  0.132044  340.000000 -0.016412 -0.044642 -0.013751 -0.009825 -0.003819
#
#                  s3        s4        s5        s6
# bp
# ...

# %%
df2.count()
# Out:
# Unnamed: 0    442
# age           442
# sex           442
# bmi           442
# bp            442
# s1            442
# s2            442
# s3            442
# s4            442
# s5            442
# s6            442
# dtype: int64

# %%
#mean value column vise
df2.std()
# Out:
# Unnamed: 0    127.738666
# age             0.047619
# sex             0.047619
# bmi             0.047619
# bp              0.047619
# s1              0.047619
# s2              0.047619
# s3              0.047619
# s4              0.047619
# s5              0.047619
# s6              0.047619
# dtype: float64

# %%
print(df2.min())
df2.max()
# Out:
# Unnamed: 0    0.000000
# age          -0.107226
# sex          -0.044642
# bmi          -0.090275
# bp           -0.112399
# s1           -0.126781
# s2           -0.115613
# s3           -0.102307
# s4           -0.076395
# s5           -0.126097
# s6           -0.137767
# dtype: float64
# Unnamed: 0    441.000000
# age             0.110727
# sex             0.050680
# bmi             0.170555
# bp              0.132044
# s1              0.153914
# s2              0.198788
# s3              0.181179
# s4              0.185234
# s5              0.133597
# s6              0.135612
# dtype: float64

# %%
df2.describe()
# Out:
#        Unnamed: 0           age           sex           bmi            bp
# count  442.000000  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  \
# mean   220.500000 -7.284269e-18  2.348549e-17 -2.087320e-16 -4.571507e-17
# std    127.738666  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min      0.000000 -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01
# 25%    110.250000 -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02
# 50%    220.500000  5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03
# 75%    330.750000  3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02
# max    441.000000  1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01
#
#                  s1            s2            s3            s4            s5
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  \
# mean  -9.293722e-18  4.420798e-17  2.135044e-18  2.913707e-17  9.143013e-17
# ...

# %% [markdown]
# #### Manipulating a DataFrame

# %%
# adding a value to dataframe
df2['price'] = ds.target
df2.head()
# Out:
#    Unnamed: 0       age       sex       bmi        bp        s1        s2
# 0           0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821  \
# 1           1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# 2           2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194
# 3           3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# 4           4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
#
#          s3        s4        s5        s6  price
# 0 -0.043401 -0.002592  0.019907 -0.017646  151.0
# 1  0.074412 -0.039493 -0.068332 -0.092204   75.0
# 2 -0.032356 -0.002592  0.002861 -0.025930  141.0
# 3 -0.036038  0.034309  0.022688 -0.009362  206.0
# 4  0.008142 -0.002592 -0.031988 -0.046641  135.0

# %%
#removing a particular row(axis=0)
df2.drop(index=0,axis=0)
# Out:
#      Unnamed: 0       age       sex       bmi        bp        s1        s2
# 1             1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  \
# 2             2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194
# 3             3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# 4             4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
# 5             5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288
# ..          ...       ...       ...       ...       ...       ...       ...
# 437         437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566
# 438         438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165
# 439         439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840
# 440         440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283
# 441         441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809
#
#            s3        s4        s5        s6  price
# ...

# %%
#removing a particular row(axis=1)
df2.drop(columns='s1',axis=1)
# Out:
#      Unnamed: 0       age       sex       bmi        bp        s2        s3
# 0             0  0.038076  0.050680  0.061696  0.021872 -0.034821 -0.043401  \
# 1             1 -0.001882 -0.044642 -0.051474 -0.026328 -0.019163  0.074412
# 2             2  0.085299  0.050680  0.044451 -0.005670 -0.034194 -0.032356
# 3             3 -0.089063 -0.044642 -0.011595 -0.036656  0.024991 -0.036038
# 4             4  0.005383 -0.044642 -0.036385  0.021872  0.015596  0.008142
# ..          ...       ...       ...       ...       ...       ...       ...
# 437         437  0.041708  0.050680  0.019662  0.059744 -0.002566 -0.028674
# 438         438 -0.005515  0.050680 -0.015906 -0.067642  0.079165 -0.028674
# 439         439  0.041708  0.050680 -0.015906  0.017293 -0.013840 -0.024993
# 440         440 -0.045472 -0.044642  0.039062  0.001215  0.015283 -0.028674
# 441         441 -0.045472 -0.044642 -0.073030 -0.081413  0.027809  0.173816
#
#            s4        s5        s6  price
# ...

# %%
#locate a particular column
print(df2.iloc[:,1])
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %% [markdown]
# #### Correlation

# %%
df2.corr()
# Out:
#             Unnamed: 0       age       sex       bmi        bp        s1
# Unnamed: 0    1.000000  0.093779  0.029867  0.058545  0.061520  0.096651  \
# age           0.093779  1.000000  0.173737  0.185085  0.335428  0.260061
# sex           0.029867  0.173737  1.000000  0.088161  0.241010  0.035277
# bmi           0.058545  0.185085  0.088161  1.000000  0.395411  0.249777
# bp            0.061520  0.335428  0.241010  0.395411  1.000000  0.242464
# s1            0.096651  0.260061  0.035277  0.249777  0.242464  1.000000
# s2            0.086569  0.219243  0.142637  0.261170  0.185548  0.896663
# s3           -0.051391 -0.075181 -0.379090 -0.366811 -0.178762  0.051519
# s4            0.098010  0.203841  0.332115  0.413807  0.257650  0.542207
# s5            0.086346  0.270774  0.149916  0.446157  0.393480  0.515503
# s6            0.092260  0.301731  0.208133  0.388680  0.390430  0.325717
# price         0.059912  0.187889  0.043062  0.586450  0.441482  0.212022
#
# ...
